# %%
from openeye.oechem import *
from openeye.oeomega import *
import pandas as pd

# Generate PDB/MOL2/SDF files for neutral microstates of SAMPL8 molecules
csv = "SAMPL8_molecule_ID_and_SMILES.csv"
redo = []

with open(csv) as file:
    #next(file)
    for line in file:
        #initialize omega, this is a conformation generator
        omega = OEOmega()
        #set the maximum conformer generated to 1
        omega.SetMaxConfs(1) 
        omega.SetIncludeInput(False)
        #Leniency in assigning atom types
        omega.SetStrictAtomTypes(False) 
        # Don't generate conformer if stereochemistry not provided
        # Setting to false would pick a random stereoisomer
        omega.SetStrictStereo(True) 

        # Generate OEMol 
        mol = OEMol()
        name = line.split(',')[0]
        smiles = line.split(',')[1].strip()
        OEParseSmiles(mol, smiles)
        #print("canonical",OECreateCanSmiString(mol))

        #Parse the SMILES string
        OEParseSmiles(mol, smiles)
        status = omega(mol)
        if not status:
            print("Error generating conformer for %s, %s." % (smiles, name))
            redo.append([name,smiles])
        
        # Write out PDB of molecule
        ofile = oemolostream('%s.pdb'%(name))
        OEWriteMolecule(ofile, mol)
        ofile.close()
        
        # Write out MOL2 of molecule
        ofile = oemolostream('%s.mol2'%(name))
        OEWriteMolecule(ofile, mol)
        ofile.close()

        # Write out SDF of molecule
        ofile = oemolostream('%s.sdf'%(name))
        OEWriteMolecule(ofile, mol)
        ofile.close()
# Out:
# Error generating conformers for isomeric SMILES, SAMPL8 Molecule ID.

# %%
# Make SDF/MOL2 files for all microstates 
import glob
from openeye.oechem import *
from openeye.oeomega import *

csv_files = glob.glob("SAMPL8-*_microstates.csv")

redo = []
for csv in csv_files:
    with open(csv) as file:
        next(file)
        for line in file:
            #initialize omega, this is a conformation generator
            omega = OEOmega()
            #set the maximum conformer generated to 1
            omega.SetMaxConfs(1) 
            omega.SetIncludeInput(False)
            #Leniency in assigning atom types
            omega.SetStrictAtomTypes(False) 
            # Don't generate conformers if stereochemistry not provided
            # Setting to false would pick a random stereoisomer
            omega.SetStrictStereo(True) 
            
            # Generate OEMol 
            mol = OEMol()
            name = line.split(',')[0]
            smiles = line.split(',')[1].strip()
            
            #Parse the SMILES string
            OEParseSmiles(mol, smiles)
            status = omega(mol)
            if not status:
                print("Error generating conformer for %s, %s." % (smiles, name))
                redo.append([name,smiles])
                
            # Write out MOL2 of molecule
            ofile = oemolostream('%s.mol2'%(name))
            OEWriteMolecule(ofile, mol)
            ofile.close()

            # Write out SDF of molecule
            ofile = oemolostream('%s.sdf'%(name))
            OEWriteMolecule(ofile, mol)
            ofile.close()
            
            # Write out PDB of molecule
            ofile = oemolostream('%s.pdb'%(name))
            OEWriteMolecule(ofile, mol)
            ofile.close()
# Out:
# Error generating conformer for CC(C)(C)OC(=NCC1=Nc2ccccc2[NH2+]1)O, SAMPL8-16_micro001.
# Error generating conformer for CC(C)(C)OC(=NC=C1Nc2ccccc2N1)O, SAMPL8-16_micro002.
# Error generating conformer for CC(C)(C)OC(=O)NC=C1[NH2+]c2ccccc2N1, SAMPL8-16_micro003.
# Error generating conformer for CC(C)(C)OC(=O)N=CC1Nc2ccccc2N1, SAMPL8-16_micro005.
# Error generating conformer for CC(C)(C)OC(=O)N=CC1[NH2+]c2ccccc2N1, SAMPL8-16_micro006.
# Error generating conformer for CC(C)(C)OC(=NCc1[nH]c2ccccc2[nH+]1)O, SAMPL8-16_micro008.
# Error generating conformer for CC(C)(C)OC(=NC=C1[NH2+]c2ccccc2N1)O, SAMPL8-16_micro009.
# Error generating conformer for CC(C)(C)OC(=NCc1[nH]c2ccccc2n1)O, SAMPL8-16_micro011.
# Error generating conformer for c1cc2c(cc1Br)n(c(=N)[n-]2)CC3(CCOCC3)O, SAMPL8-7_micro001.
# Error generating conformer for c1cc2c(cc1Br)n(c(=N)[nH]2)CC3(CCOCC3)O, SAMPL8-7_micro004.
# Error generating conformer for COC(=C1C=[n+]2cccc(c2=[NH+]1)C(F)(F)F)[O-], SAMPL8-8_micro001.
# Error generating conformer for COC(=C1C=[n+]2cccc(c2=N1)C(F)(F)F)O, SAMPL8-8_micro002.
# Error generating conformer for CN1c2ccccc2NC1=CSc3[nH]c(=O)c(cn3)Cc4cnc(nc4)OC, SAMPL8-19_micro000.
# Error generating conformer for CN1c2ccccc2[NH2+]C1=CSc3[nH]cc(c(=O)n3)Cc4cnc(nc4)OC, SAMPL8-19_micro001.
# Error generating conformer for CN1c2ccccc2NC1=CSc3[nH+]cc(c(n3)O)Cc4cnc(nc4)OC, SAMPL8-19_micro004.
# Error generating conformer for CN1c2ccccc2NC1=CSc3[n-]c(=O)c(cn3)Cc4cnc(nc4)OC, SAMPL8-19_micro010.
# Error generating conformer for CN1c2ccccc2[NH2+]C1=CSc3[nH]c(=O)c(c[nH+]3)Cc4cnc(nc4)OC, SAMPL8-19_micro012.
# Error generating conformer for CN1c2ccccc2[NH2+]C1=CSc3[n-]c(=O)c(cn3)Cc4cnc(nc4)OC, SAMPL8-19_micro014.
# Error generating conformer for CN1c2ccccc2[NH2+]C1=CSc3[nH]c(=O)c(cn3)Cc4cnc(nc4)OC, SAMPL8-19_micro016.
# Error generating conformer for CN1c2ccccc2NC1=CSc3ncc(c(n3)O)Cc4cnc(nc4)OC, SAMPL8-19_micro020.
# Error generating conformer for CN1c2ccccc2[NH2+]C1=CSc3[nH+]cc(c(n3)O)Cc4cnc(nc4)OC, SAMPL8-19_micro021.
# Error generating conformer for CN1c2ccccc2NC1=CSc3[nH]c(=O)c(c[nH+]3)Cc4cnc(nc4)OC, SAMPL8-19_micro022.
# Error generating conformer for CN1c2ccccc2[NH2+]C1=CSc3ncc(c(n3)O)Cc4cnc(nc4)OC, SAMPL8-19_micro023.
# Error generating conformer for CN1c2ccccc2NC1=CSc3[nH]cc(c(=O)n3)Cc4cnc(nc4)OC, SAMPL8-19_micro025.
# Error generating conformer for COc1cc2c(cc1OC)nc([nH]c2=N)Cl, SAMPL8-22_micro000.
# Error generating conformer for COc1cc2c(cc1OC)[n-]c(nc2=N)Cl, SAMPL8-22_micro001.
# Error generating conformer for COc1cc2c(cc1OC)[nH]c(nc2=N)Cl, SAMPL8-22_micro003.
# Error generating conformer for c1cc(cc(c1)N=C2C=CC=CC2C(=O)[O-])C(F)(F)F, SAMPL8-1_micro001.
# Error generating conformer for c1cc(cc(c1)N=C2C=CC=CC2=C(O)[O-])C(F)(F)F, SAMPL8-1_micro002.
# Error generating conformer for c1cc(cc(c1)N=C2CC=CC=C2C(=O)[O-])C(F)(F)F, SAMPL8-1_micro003.
# Error generating conformer for c1cc(cc(c1)[NH+]=C2C=CC=CC2=C([O-])[O-])C(F)(F)F, SAMPL8-1_micro005.
# Error generating conformer for c1cc(cc(c1)N=C2C=CC=CC2=C(O)O)C(F)(F)F, SAMPL8-1_micro006.
# Error generating conformer for c1cc(cc(c1)N=C2CC=CC=C2C(=O)O)C(F)(F)F, SAMPL8-1_micro007.
# Error generating conformer for c1cc(cc(c1)N=C2C=CCC=C2C(=O)[O-])C(F)(F)F, SAMPL8-1_micro008.
# Error generating conformer for c1cc(cc(c1)N=C2C=CC=CC2C(=O)O)C(F)(F)F, SAMPL8-1_micro009.
# Error generating conformer for c1cc(cc(c1)N=C2C=CCC=C2C(=O)O)C(F)(F)F, SAMPL8-1_micro010.
# Error generating conformer for c1cc2c(cc1Br)n(c(=N)[nH]2)CC3(CCOCC3)CO, SAMPL8-17_micro004.
# Error generating conformer for Cc1ccc(cc1[NH2+]C=c2ccc(=C(O)O)s2)Cl, SAMPL8-6_micro002.
# Error generating conformer for Cc1ccc(cc1[NH2+]C=c2ccc(=C(O)[O-])s2)Cl, SAMPL8-6_micro004.
# Error generating conformer for Cc1ccc(cc1NC=c2ccc(=C(O)O)s2)Cl, SAMPL8-6_micro005.
# Error generating conformer for Cc1ccc(cc1N=Cc2ccc(s2)C(O)[O-])Cl, SAMPL8-6_micro006.
# Error generating conformer for Cc1ccc(cc1N=Cc2ccc(s2)C(O)O)Cl, SAMPL8-6_micro008.
# Error generating conformer for Cc1ccc(cc1NC=c2ccc(=C(O)[O-])s2)Cl, SAMPL8-6_micro009.
# Error generating conformer for c1cc2c(cc1Br)n(c(=N)[n-]2)CC3(CCCCC3)O, SAMPL8-9_micro001.
# Error generating conformer for c1cc2c(cc1Br)n(c(=N)[nH]2)CC3(CCCCC3)O, SAMPL8-9_micro003.
# Error generating conformer for COc1ccc(cc1OC)N=c2c3ccccc3nc([nH]2)Cl, SAMPL8-18_micro000.
# Error generating conformer for COc1ccc(cc1OC)N=c2c3ccccc3[nH]c(n2)Cl, SAMPL8-18_micro001.
# Error generating conformer for c1ccc(cc1)c2c(cc3c(=N)[nH][nH]c3n2)Cl, SAMPL8-20_micro000.
# Error generating conformer for c1ccc(cc1)c2c(cc-3c(=N)[nH]nc3[nH]2)Cl, SAMPL8-20_micro001.
# Error generating conformer for c1ccc(cc1)C2=NC3=NN=C(C3=CC2Cl)N, SAMPL8-20_micro004.
# Error generating conformer for c1ccc(cc1)C2=C(CC3C(=[NH2+])N=NC3=N2)Cl, SAMPL8-20_micro005.
# Error generating conformer for c1ccc(cc1)C2=NC3=NNC(=[NH2+])C3C=C2Cl, SAMPL8-20_micro007.
# Error generating conformer for c1ccc(cc1)C2C(C=C3C(=N)N=NC3=N2)Cl, SAMPL8-20_micro008.
# Error generating conformer for c1ccc(cc1)C2=NC3=NNC(=N)C3=CC2Cl, SAMPL8-20_micro009.
# Error generating conformer for c1ccc(cc1)C2=C(CC3=C(N2)N=NC3=N)Cl, SAMPL8-20_micro012.
# Error generating conformer for c1ccc(cc1)C2=NC3=NNC(=N)C3C=C2Cl, SAMPL8-20_micro013.
# Error generating conformer for c1ccc(cc1)C2=NC3=C(CC2Cl)C(=[NH2+])N=N3, SAMPL8-20_micro014.
# Error generating conformer for c1ccc(cc1)c2c(cc-3c(=N)[nH][nH+]c3[nH]2)Cl, SAMPL8-20_micro016.
# Error generating conformer for c1ccc(cc1)C2C(=CC3=C(N=NC3=N2)N)Cl, SAMPL8-20_micro019.
# Error generating conformer for c1ccc(cc1)C2C(=CC3C(=N)N=NC3=N2)Cl, SAMPL8-20_micro020.
# Error generating conformer for c1ccc(cc1)C2=NC3=NN=C(C3C=C2Cl)N, SAMPL8-20_micro021.
# Error generating conformer for c1ccc(cc1)C2C(=CC3=C(N2)N=NC3=N)Cl, SAMPL8-20_micro023.
# Error generating conformer for c1ccc(cc1)C2=NC3=C(CC2Cl)C(=N)N=N3, SAMPL8-20_micro024.
# Error generating conformer for c1ccc(cc1)C2=C(CC3C(=N)N=NC3=N2)Cl, SAMPL8-20_micro027.
# Error generating conformer for c1cc(oc1)CN=C2C=C(C(=CC2=C(O)O)S(=O)(=O)N)Cl, SAMPL8-3_micro000.
# Error generating conformer for c1cc(oc1)CN=C2CC(=C(C=C2C(=O)[O-])S(=O)(=O)N)Cl, SAMPL8-3_micro001.
# Error generating conformer for c1cc(oc1)CN=C2CC(=C(C=C2C(=O)O)S(=O)(=O)N)Cl, SAMPL8-3_micro002.
# Error generating conformer for c1cc(oc1)CN=C2CC(=C(C=C2C(=O)O)S(=O)(=O)[NH-])Cl, SAMPL8-3_micro003.
# Error generating conformer for c1cc(oc1)CN=C2C=C(C(C=C2C(=O)O)S(=O)(=O)N)Cl, SAMPL8-3_micro004.
# Error generating conformer for c1cc(oc1)CN=C2C=C(C(=CC2=C(O)[O-])S(=O)(=O)N)Cl, SAMPL8-3_micro005.
# Error generating conformer for c1cc(oc1)CN=C2C=C(C(C=C2C(=O)[O-])S(=O)(=O)[NH-])Cl, SAMPL8-3_micro007.
# Error generating conformer for c1cc(oc1)CN=C2C=C(C(=CC2C(=O)O)S(=O)(=O)N)Cl, SAMPL8-3_micro008.
# Error generating conformer for c1cc(oc1)CN=C2C=C(C(=CC2C(=O)[O-])S(=O)(=O)N)Cl, SAMPL8-3_micro009.
# Error generating conformer for c1cc(oc1)CN=C2C=C(C(C=C2C(=O)O)S(=O)(=O)[NH-])Cl, SAMPL8-3_micro011.
# Error generating conformer for c1cc(oc1)CN=C2C=C(C(=CC2=C(O)[O-])S(=O)(=O)[NH-])Cl, SAMPL8-3_micro012.
# Error generating conformer for c1cc(oc1)C[NH+]=C2C=C(C(=CC2=C([O-])[O-])S(=O)(=O)[NH-])Cl, SAMPL8-3_micro013.
# Error generating conformer for c1cc(oc1)CN=C2C=C(C(=CC2=C(O)O)S(=O)(=O)[NH-])Cl, SAMPL8-3_micro015.
# Error generating conformer for c1cc(oc1)CN=C2C=C(C(=CC2C(=O)O)S(=O)(=O)[NH-])Cl, SAMPL8-3_micro017.
# Error generating conformer for c1cc(oc1)CN=C2C=C(C(C=C2C(=O)[O-])S(=O)(=O)N)Cl, SAMPL8-3_micro018.
# Error generating conformer for c1cc(oc1)CN=C2CC(=C(C=C2C(=O)[O-])S(=O)(=O)[NH-])Cl, SAMPL8-3_micro019.
# Error generating conformer for c1cc(oc1)C[NH+]=C2C=C(C(=CC2=C([O-])[O-])S(=O)(=O)N)Cl, SAMPL8-3_micro020.
# Error generating conformer for c1cc(oc1)CN=C2C=C(C(=CC2C(=O)[O-])S(=O)(=O)[NH-])Cl, SAMPL8-3_micro021.
# Error generating conformer for Cc1ccc(cc1)Cc2cnc(=N)[nH]c2N3CCOCC3, SAMPL8-12_micro002.
# Error generating conformer for Cc1ccc(cc1)Cc2c[nH]c(=N)nc2N3CCOCC3, SAMPL8-12_micro003.
# Error generating conformer for Cc1ccccc1N=c2c3ccccc3[nH]c(n2)Cl, SAMPL8-15_micro000.
# Error generating conformer for Cc1ccccc1N=c2c3ccccc3nc([nH]2)Cl, SAMPL8-15_micro002.
# Error generating conformer for Cc1c([nH]c(=Nc2ccc(c(c2)Cl)C#N)s1)C(=O)O, SAMPL8-4_micro000.
# Error generating conformer for Cc1c([nH]c(=Nc2ccc(c(c2)Cl)C#N)s1)C(=O)[O-], SAMPL8-4_micro003.
# Error generating conformer for Cc1c([nH]c(=Nc2ccc(c(c2)Cl)C#N)s1)C(=O)O, SAMPL8-4_micro004.
# Error generating conformer for Cc1c(nc(s1)[NH+]=C2C=CC(=C=[N-])C(=C2)Cl)C(=O)[O-], SAMPL8-4_micro006.
# Error generating conformer for Cc1c([nH+]c(s1)[NH+]=C2C=CC(=C=[N-])C(=C2)Cl)C(=O)O, SAMPL8-4_micro007.
# Error generating conformer for Cc1c(nc(s1)N=C2C=CC(=C=[N-])C(=C2)Cl)C(=O)O, SAMPL8-4_micro008.
# Error generating conformer for Cc1c([nH+]c(s1)N=C2C=CC(=C=[N-])C(=C2)Cl)C(=O)[O-], SAMPL8-4_micro009.
# Error generating conformer for Cc1cc(cc(c1O)C(C)(C)C)Cc2cnc(=N)[nH]c2N, SAMPL8-14_micro000.
# Error generating conformer for Cc1cc(cc(c1[O-])C(C)(C)C)Cc2cnc(=N)[n-]c2N, SAMPL8-14_micro001.
# Error generating conformer for Cc1cc(cc(c1O)C(C)(C)C)Cc2cnc([nH]c2=N)N, SAMPL8-14_micro002.
# Error generating conformer for Cc1cc(cc(c1[O-])C(C)(C)C)Cc2c[n-]c(nc2=N)N, SAMPL8-14_micro003.
# Error generating conformer for Cc1cc(cc(c1O)C(C)(C)C)Cc2c[nH]c(=N)[nH]c2=N, SAMPL8-14_micro006.
# Error generating conformer for Cc1cc(cc(c1[O-])C(C)(C)C)Cc2cnc([nH]c2=N)[NH-], SAMPL8-14_micro007.
# Error generating conformer for Cc1cc(cc(c1O)C(C)(C)C)Cc2c[nH]c(=N)[n-]c2=N, SAMPL8-14_micro09.
# Error generating conformer for Cc1cc(cc(c1O)C(C)(C)C)Cc2c[n-]c(nc2=N)N, SAMPL8-14_micro010.
# Error generating conformer for Cc1cc(cc(c1O)C(C)(C)C)Cc2c[nH]c(=N)nc2N, SAMPL8-14_micro013.
# Error generating conformer for Cc1cc(cc(c1[O-])C(C)(C)C)Cc2cnc(=N)[n-]c2[NH-], SAMPL8-14_micro014.
# Error generating conformer for Cc1cc(cc(c1[O-])C(C)(C)C)Cc2c[n-]c([nH+]c2=N)[NH-], SAMPL8-14_micro015.
# Error generating conformer for Cc1cc(cc(c1O)C(C)(C)C)Cc2cnc(=N)[nH]c2N, SAMPL8-14_micro016.
# Error generating conformer for Cc1cc(cc(c1O)C(C)(C)C)Cc2c[nH]c(nc2=N)N, SAMPL8-14_micro017.
# Error generating conformer for Cc1cc(cc(c1O)C(C)(C)C)Cc2cnc([n-]c2=N)[NH-], SAMPL8-14_micro018.
# Error generating conformer for Cc1cc(cc(c1[O-])C(C)(C)C)Cc2c[nH]c(=N)[n-]c2=N, SAMPL8-14_micro020.
# Error generating conformer for Cc1cc(cc(c1O)C(C)(C)C)Cc2cnc([nH]c2=N)[NH-], SAMPL8-14_micro021.
# Error generating conformer for Cc1cc(cc(c1[O-])C(C)(C)C)Cc2c[nH]c(nc2=N)N, SAMPL8-14_micro022.
# Error generating conformer for Cc1cc(cc(c1O)C(C)(C)C)Cc2cnc([nH]c2=N)N, SAMPL8-14_micro023.
# Error generating conformer for Cc1cc(cc(c1O)C(C)(C)C)Cc2c[n-]c([nH+]c2=N)[NH-], SAMPL8-14_micro025.
# Error generating conformer for Cc1cc(cc(c1[O-])C(C)(C)C)Cc2c[nH+]c(=N)[n-]c2[NH-], SAMPL8-14_micro026.
# Error generating conformer for Cc1cc(cc(c1[O-])C(C)(C)C)Cc2c[nH]c(=N)[nH]c2=N, SAMPL8-14_micro027.
# Error generating conformer for Cc1cc(cc(c1[O-])C(C)(C)C)Cc2c[nH]c(=N)nc2N, SAMPL8-14_micro028.
# Error generating conformer for Cc1cc(cc(c1[O-])C(C)(C)C)Cc2cnc(=N)[nH]c2N, SAMPL8-14_micro029.
# Error generating conformer for Cc1cc(cc(c1O)C(C)(C)C)Cc2c[nH]c(nc2=N)N, SAMPL8-14_micro030.
# Error generating conformer for Cc1cc(cc(c1[O-])C(C)(C)C)Cc2cnc([nH]c2=N)N, SAMPL8-14_micro032.
# Error generating conformer for Cc1cc(cc(c1O)C(C)(C)C)Cc2c[nH]c(=N)nc2N, SAMPL8-14_micro033.
# Error generating conformer for Cc1cc(cc(c1O)C(C)(C)C)Cc2c[nH]c(=N)[nH]c2=N, SAMPL8-14_micro034.
# Error generating conformer for c1ccc(c(c1)C=C(O)[O-])Nc2c(cccc2Cl)Cl, SAMPL8-5_micro002.
# Error generating conformer for c1ccc(c(c1)C=C(O)[O-])[NH2+]c2c(cccc2Cl)Cl, SAMPL8-5_micro004.
# Error generating conformer for COc1cc(cc(c1O)OC)Cc2c(=N)[nH]c(=N)[nH]c2OC, SAMPL8-21_micro000.
# Error generating conformer for COc1cc(cc(c1[O-])OC)Cc2c(=N)[nH+]c([n-]c2OC)[NH-], SAMPL8-21_micro001.
# Error generating conformer for COc1cc(cc(c1[O-])OC)Cc2c(=N)nc([nH]c2OC)[NH-], SAMPL8-21_micro004.
# Error generating conformer for COc1cc(cc(c1[O-])OC)Cc2c(=N)[n-]c(=[NH2+])[n-]c2OC, SAMPL8-21_micro005.
# Error generating conformer for COc1cc(cc(c1O)OC)Cc2c(=N)[nH]c(=N)[n-]c2OC, SAMPL8-21_micro006.
# Error generating conformer for COc1cc(cc(c1O)OC)Cc2c(=N)[n-]c(=N)[nH]c2OC, SAMPL8-21_micro007.
# Error generating conformer for COc1cc(cc(c1O)OC)Cc2c(=N)nc([nH]c2OC)N, SAMPL8-21_micro008.
# Error generating conformer for COc1cc(cc(c1[O-])OC)Cc2c(=N)[n-]c(nc2OC)[NH-], SAMPL8-21_micro010.
# Error generating conformer for COc1cc(cc(c1O)OC)Cc2c([nH+]c(=N)[n-]c2OC)[NH-], SAMPL8-21_micro011.
# Error generating conformer for COc1cc(cc(c1O)OC)Cc2c(=N)nc([n-]c2OC)[NH-], SAMPL8-21_micro012.
# Error generating conformer for COc1cc(cc(c1[O-])OC)Cc2c(=N)[nH]c(nc2OC)[NH-], SAMPL8-21_micro013.
# Error generating conformer for COc1cc(cc(c1O)OC)Cc2c([n-]c(=N)nc2OC)N, SAMPL8-21_micro014.
# Error generating conformer for COc1cc(cc(c1[O-])OC)Cc2c(nc(=N)[n-]c2OC)N, SAMPL8-21_micro017.
# Error generating conformer for COc1cc(cc(c1[O-])OC)Cc2c(=N)[nH]c(nc2OC)N, SAMPL8-21_micro018.
# Error generating conformer for COc1cc(cc(c1O)OC)Cc2c([n-]c(=N)[nH+]c2OC)[NH-], SAMPL8-21_micro019.
# Error generating conformer for COc1cc(cc(c1[O-])OC)Cc2c(nc(=N)[nH]c2OC)N, SAMPL8-21_micro020.
# Error generating conformer for COc1cc(cc(c1[O-])OC)Cc2c(=N)[n-]c(nc2OC)N, SAMPL8-21_micro021.
# Error generating conformer for COc1cc(cc(c1O)OC)Cc2c(=N)[nH]c(nc2OC)N, SAMPL8-21_micro023.
# Error generating conformer for COc1cc(cc(c1[O-])OC)Cc2c([nH]c(=N)nc2OC)N, SAMPL8-21_micro024.
# Error generating conformer for COc1cc(cc(c1O)OC)Cc2c([nH]c(=N)nc2OC)N, SAMPL8-21_micro025.
# Error generating conformer for COc1cc(cc(c1[O-])OC)Cc2c(=N)nc([nH]c2OC)N, SAMPL8-21_micro026.
# Error generating conformer for COc1cc(cc(c1[O-])OC)Cc2c(=N)[nH]c(=N)[nH]c2OC, SAMPL8-21_micro027.
# Error generating conformer for COc1cc(cc(c1O)OC)Cc2c(nc(=N)[nH]c2OC)N, SAMPL8-21_micro029.
# Error generating conformer for CS(=O)(=O)c1ccc(cc1)CC=C(O)[O-], SAMPL8-2_micro003.

# %%
# If there were problems with conformer generation due to sterochemistry, 
# then a random stereoisomer was chosen 
for pair in redo:
    #initialize omega, this is a conformation generator
    omega = OEOmega()
    
    #set the maximum conformer generated to 1
    omega.SetMaxConfs(1) 
    omega.SetIncludeInput(False)
    
    #Leniency in assigning atom types
    omega.SetStrictAtomTypes(False) 
    
    # Don't generate conformers if stereochemistry not provided
    # Setting to false would pick a random stereoisomer
    omega.SetStrictStereo(False) 

    # Generate OEMol 
    mol = OEMol()
    name = pair[0]
    smiles = pair[1]

    #Parse the SMILES string
    OEParseSmiles(mol, smiles)
    status = omega(mol)
    if not status:
        print("Error generating conformer for %s, %s." % (smiles, name))
    else:
        print("Conformer generated for %s, %s." % (smiles, name))
        

    # Write out MOL2 of molecule
    ofile = oemolostream('%s.mol2'%(name))
    OEWriteMolecule(ofile, mol)
    ofile.close()

    # Write out SDF of molecule
    ofile = oemolostream('%s.sdf'%(name))
    OEWriteMolecule(ofile, mol)
    ofile.close()
    
    # Write out PDB of molecule
    ofile = oemolostream('%s.pdb'%(name))
    OEWriteMolecule(ofile, mol)
    ofile.close()
# Out:
# Conformer generated for CC(C)(C)OC(=NCC1=Nc2ccccc2[NH2+]1)O, SAMPL8-16_micro001.
# Conformer generated for CC(C)(C)OC(=NC=C1Nc2ccccc2N1)O, SAMPL8-16_micro002.
# Conformer generated for CC(C)(C)OC(=O)NC=C1[NH2+]c2ccccc2N1, SAMPL8-16_micro003.
# Conformer generated for CC(C)(C)OC(=O)N=CC1Nc2ccccc2N1, SAMPL8-16_micro005.
# Conformer generated for CC(C)(C)OC(=O)N=CC1[NH2+]c2ccccc2N1, SAMPL8-16_micro006.
# Conformer generated for CC(C)(C)OC(=NCc1[nH]c2ccccc2[nH+]1)O, SAMPL8-16_micro008.
# Conformer generated for CC(C)(C)OC(=NC=C1[NH2+]c2ccccc2N1)O, SAMPL8-16_micro009.
# Conformer generated for CC(C)(C)OC(=NCc1[nH]c2ccccc2n1)O, SAMPL8-16_micro011.
# Conformer generated for c1cc2c(cc1Br)n(c(=N)[n-]2)CC3(CCOCC3)O, SAMPL8-7_micro001.
# Conformer generated for c1cc2c(cc1Br)n(c(=N)[nH]2)CC3(CCOCC3)O, SAMPL8-7_micro004.
# Conformer generated for COC(=C1C=[n+]2cccc(c2=[NH+]1)C(F)(F)F)[O-], SAMPL8-8_micro001.
# Conformer generated for COC(=C1C=[n+]2cccc(c2=N1)C(F)(F)F)O, SAMPL8-8_micro002.
# Conformer generated for CN1c2ccccc2NC1=CSc3[nH]c(=O)c(cn3)Cc4cnc(nc4)OC, SAMPL8-19_micro000.
# Conformer generated for CN1c2ccccc2[NH2+]C1=CSc3[nH]cc(c(=O)n3)Cc4cnc(nc4)OC, SAMPL8-19_micro001.
# Conformer generated for CN1c2ccccc2NC1=CSc3[nH+]cc(c(n3)O)Cc4cnc(nc4)OC, SAMPL8-19_micro004.
# Conformer generated for CN1c2ccccc2NC1=CSc3[n-]c(=O)c(cn3)Cc4cnc(nc4)OC, SAMPL8-19_micro010.
# Conformer generated for CN1c2ccccc2[NH2+]C1=CSc3[nH]c(=O)c(c[nH+]3)Cc4cnc(nc4)OC, SAMPL8-19_micro012.
# Conformer generated for CN1c2ccccc2[NH2+]C1=CSc3[n-]c(=O)c(cn3)Cc4cnc(nc4)OC, SAMPL8-19_micro014.
# Conformer generated for CN1c2ccccc2[NH2+]C1=CSc3[nH]c(=O)c(cn3)Cc4cnc(nc4)OC, SAMPL8-19_micro016.
# Conformer generated for CN1c2ccccc2NC1=CSc3ncc(c(n3)O)Cc4cnc(nc4)OC, SAMPL8-19_micro020.
# Conformer generated for CN1c2ccccc2[NH2+]C1=CSc3[nH+]cc(c(n3)O)Cc4cnc(nc4)OC, SAMPL8-19_micro021.
# Conformer generated for CN1c2ccccc2NC1=CSc3[nH]c(=O)c(c[nH+]3)Cc4cnc(nc4)OC, SAMPL8-19_micro022.
# Conformer generated for CN1c2ccccc2[NH2+]C1=CSc3ncc(c(n3)O)Cc4cnc(nc4)OC, SAMPL8-19_micro023.
# Conformer generated for CN1c2ccccc2NC1=CSc3[nH]cc(c(=O)n3)Cc4cnc(nc4)OC, SAMPL8-19_micro025.
# Conformer generated for COc1cc2c(cc1OC)nc([nH]c2=N)Cl, SAMPL8-22_micro000.
# Conformer generated for COc1cc2c(cc1OC)[n-]c(nc2=N)Cl, SAMPL8-22_micro001.
# Conformer generated for COc1cc2c(cc1OC)[nH]c(nc2=N)Cl, SAMPL8-22_micro003.
# Conformer generated for c1cc(cc(c1)N=C2C=CC=CC2C(=O)[O-])C(F)(F)F, SAMPL8-1_micro001.
# Conformer generated for c1cc(cc(c1)N=C2C=CC=CC2=C(O)[O-])C(F)(F)F, SAMPL8-1_micro002.
# Conformer generated for c1cc(cc(c1)N=C2CC=CC=C2C(=O)[O-])C(F)(F)F, SAMPL8-1_micro003.
# Conformer generated for c1cc(cc(c1)[NH+]=C2C=CC=CC2=C([O-])[O-])C(F)(F)F, SAMPL8-1_micro005.
# Conformer generated for c1cc(cc(c1)N=C2C=CC=CC2=C(O)O)C(F)(F)F, SAMPL8-1_micro006.
# Conformer generated for c1cc(cc(c1)N=C2CC=CC=C2C(=O)O)C(F)(F)F, SAMPL8-1_micro007.
# Conformer generated for c1cc(cc(c1)N=C2C=CCC=C2C(=O)[O-])C(F)(F)F, SAMPL8-1_micro008.
# Conformer generated for c1cc(cc(c1)N=C2C=CC=CC2C(=O)O)C(F)(F)F, SAMPL8-1_micro009.
# Conformer generated for c1cc(cc(c1)N=C2C=CCC=C2C(=O)O)C(F)(F)F, SAMPL8-1_micro010.
# Conformer generated for c1cc2c(cc1Br)n(c(=N)[nH]2)CC3(CCOCC3)CO, SAMPL8-17_micro004.
# Conformer generated for Cc1ccc(cc1[NH2+]C=c2ccc(=C(O)O)s2)Cl, SAMPL8-6_micro002.
# Conformer generated for Cc1ccc(cc1[NH2+]C=c2ccc(=C(O)[O-])s2)Cl, SAMPL8-6_micro004.
# Conformer generated for Cc1ccc(cc1NC=c2ccc(=C(O)O)s2)Cl, SAMPL8-6_micro005.
# Conformer generated for Cc1ccc(cc1N=Cc2ccc(s2)C(O)[O-])Cl, SAMPL8-6_micro006.
# Conformer generated for Cc1ccc(cc1N=Cc2ccc(s2)C(O)O)Cl, SAMPL8-6_micro008.
# Conformer generated for Cc1ccc(cc1NC=c2ccc(=C(O)[O-])s2)Cl, SAMPL8-6_micro009.
# Conformer generated for c1cc2c(cc1Br)n(c(=N)[n-]2)CC3(CCCCC3)O, SAMPL8-9_micro001.
# Conformer generated for c1cc2c(cc1Br)n(c(=N)[nH]2)CC3(CCCCC3)O, SAMPL8-9_micro003.
# Conformer generated for COc1ccc(cc1OC)N=c2c3ccccc3nc([nH]2)Cl, SAMPL8-18_micro000.
# Conformer generated for COc1ccc(cc1OC)N=c2c3ccccc3[nH]c(n2)Cl, SAMPL8-18_micro001.
# Conformer generated for c1ccc(cc1)c2c(cc3c(=N)[nH][nH]c3n2)Cl, SAMPL8-20_micro000.
# Conformer generated for c1ccc(cc1)c2c(cc-3c(=N)[nH]nc3[nH]2)Cl, SAMPL8-20_micro001.
# Conformer generated for c1ccc(cc1)C2=NC3=NN=C(C3=CC2Cl)N, SAMPL8-20_micro004.
# Conformer generated for c1ccc(cc1)C2=C(CC3C(=[NH2+])N=NC3=N2)Cl, SAMPL8-20_micro005.
# Conformer generated for c1ccc(cc1)C2=NC3=NNC(=[NH2+])C3C=C2Cl, SAMPL8-20_micro007.
# Conformer generated for c1ccc(cc1)C2C(C=C3C(=N)N=NC3=N2)Cl, SAMPL8-20_micro008.
# Conformer generated for c1ccc(cc1)C2=NC3=NNC(=N)C3=CC2Cl, SAMPL8-20_micro009.
# Conformer generated for c1ccc(cc1)C2=C(CC3=C(N2)N=NC3=N)Cl, SAMPL8-20_micro012.
# Conformer generated for c1ccc(cc1)C2=NC3=NNC(=N)C3C=C2Cl, SAMPL8-20_micro013.
# Conformer generated for c1ccc(cc1)C2=NC3=C(CC2Cl)C(=[NH2+])N=N3, SAMPL8-20_micro014.
# Conformer generated for c1ccc(cc1)c2c(cc-3c(=N)[nH][nH+]c3[nH]2)Cl, SAMPL8-20_micro016.
# Conformer generated for c1ccc(cc1)C2C(=CC3=C(N=NC3=N2)N)Cl, SAMPL8-20_micro019.
# Conformer generated for c1ccc(cc1)C2C(=CC3C(=N)N=NC3=N2)Cl, SAMPL8-20_micro020.
# Conformer generated for c1ccc(cc1)C2=NC3=NN=C(C3C=C2Cl)N, SAMPL8-20_micro021.
# Conformer generated for c1ccc(cc1)C2C(=CC3=C(N2)N=NC3=N)Cl, SAMPL8-20_micro023.
# Conformer generated for c1ccc(cc1)C2=NC3=C(CC2Cl)C(=N)N=N3, SAMPL8-20_micro024.
# Conformer generated for c1ccc(cc1)C2=C(CC3C(=N)N=NC3=N2)Cl, SAMPL8-20_micro027.
# Conformer generated for c1cc(oc1)CN=C2C=C(C(=CC2=C(O)O)S(=O)(=O)N)Cl, SAMPL8-3_micro000.
# Conformer generated for c1cc(oc1)CN=C2CC(=C(C=C2C(=O)[O-])S(=O)(=O)N)Cl, SAMPL8-3_micro001.
# Conformer generated for c1cc(oc1)CN=C2CC(=C(C=C2C(=O)O)S(=O)(=O)N)Cl, SAMPL8-3_micro002.
# Conformer generated for c1cc(oc1)CN=C2CC(=C(C=C2C(=O)O)S(=O)(=O)[NH-])Cl, SAMPL8-3_micro003.
# Conformer generated for c1cc(oc1)CN=C2C=C(C(C=C2C(=O)O)S(=O)(=O)N)Cl, SAMPL8-3_micro004.
# Conformer generated for c1cc(oc1)CN=C2C=C(C(=CC2=C(O)[O-])S(=O)(=O)N)Cl, SAMPL8-3_micro005.
# Conformer generated for c1cc(oc1)CN=C2C=C(C(C=C2C(=O)[O-])S(=O)(=O)[NH-])Cl, SAMPL8-3_micro007.
# Conformer generated for c1cc(oc1)CN=C2C=C(C(=CC2C(=O)O)S(=O)(=O)N)Cl, SAMPL8-3_micro008.
# Conformer generated for c1cc(oc1)CN=C2C=C(C(=CC2C(=O)[O-])S(=O)(=O)N)Cl, SAMPL8-3_micro009.
# Conformer generated for c1cc(oc1)CN=C2C=C(C(C=C2C(=O)O)S(=O)(=O)[NH-])Cl, SAMPL8-3_micro011.
# Conformer generated for c1cc(oc1)CN=C2C=C(C(=CC2=C(O)[O-])S(=O)(=O)[NH-])Cl, SAMPL8-3_micro012.
# Conformer generated for c1cc(oc1)C[NH+]=C2C=C(C(=CC2=C([O-])[O-])S(=O)(=O)[NH-])Cl, SAMPL8-3_micro013.
# Conformer generated for c1cc(oc1)CN=C2C=C(C(=CC2=C(O)O)S(=O)(=O)[NH-])Cl, SAMPL8-3_micro015.
# Conformer generated for c1cc(oc1)CN=C2C=C(C(=CC2C(=O)O)S(=O)(=O)[NH-])Cl, SAMPL8-3_micro017.
# Conformer generated for c1cc(oc1)CN=C2C=C(C(C=C2C(=O)[O-])S(=O)(=O)N)Cl, SAMPL8-3_micro018.
# Conformer generated for c1cc(oc1)CN=C2CC(=C(C=C2C(=O)[O-])S(=O)(=O)[NH-])Cl, SAMPL8-3_micro019.
# Conformer generated for c1cc(oc1)C[NH+]=C2C=C(C(=CC2=C([O-])[O-])S(=O)(=O)N)Cl, SAMPL8-3_micro020.
# Conformer generated for c1cc(oc1)CN=C2C=C(C(=CC2C(=O)[O-])S(=O)(=O)[NH-])Cl, SAMPL8-3_micro021.
# Conformer generated for Cc1ccc(cc1)Cc2cnc(=N)[nH]c2N3CCOCC3, SAMPL8-12_micro002.
# Conformer generated for Cc1ccc(cc1)Cc2c[nH]c(=N)nc2N3CCOCC3, SAMPL8-12_micro003.
# Conformer generated for Cc1ccccc1N=c2c3ccccc3[nH]c(n2)Cl, SAMPL8-15_micro000.
# Conformer generated for Cc1ccccc1N=c2c3ccccc3nc([nH]2)Cl, SAMPL8-15_micro002.
# Conformer generated for Cc1c([nH]c(=Nc2ccc(c(c2)Cl)C#N)s1)C(=O)O, SAMPL8-4_micro000.
# Conformer generated for Cc1c([nH]c(=Nc2ccc(c(c2)Cl)C#N)s1)C(=O)[O-], SAMPL8-4_micro003.
# Conformer generated for Cc1c([nH]c(=Nc2ccc(c(c2)Cl)C#N)s1)C(=O)O, SAMPL8-4_micro004.
# Conformer generated for Cc1c(nc(s1)[NH+]=C2C=CC(=C=[N-])C(=C2)Cl)C(=O)[O-], SAMPL8-4_micro006.
# Conformer generated for Cc1c([nH+]c(s1)[NH+]=C2C=CC(=C=[N-])C(=C2)Cl)C(=O)O, SAMPL8-4_micro007.
# Conformer generated for Cc1c(nc(s1)N=C2C=CC(=C=[N-])C(=C2)Cl)C(=O)O, SAMPL8-4_micro008.
# Conformer generated for Cc1c([nH+]c(s1)N=C2C=CC(=C=[N-])C(=C2)Cl)C(=O)[O-], SAMPL8-4_micro009.
# Conformer generated for Cc1cc(cc(c1O)C(C)(C)C)Cc2cnc(=N)[nH]c2N, SAMPL8-14_micro000.
# Conformer generated for Cc1cc(cc(c1[O-])C(C)(C)C)Cc2cnc(=N)[n-]c2N, SAMPL8-14_micro001.
# Conformer generated for Cc1cc(cc(c1O)C(C)(C)C)Cc2cnc([nH]c2=N)N, SAMPL8-14_micro002.
# Conformer generated for Cc1cc(cc(c1[O-])C(C)(C)C)Cc2c[n-]c(nc2=N)N, SAMPL8-14_micro003.
# Conformer generated for Cc1cc(cc(c1O)C(C)(C)C)Cc2c[nH]c(=N)[nH]c2=N, SAMPL8-14_micro006.
# Conformer generated for Cc1cc(cc(c1[O-])C(C)(C)C)Cc2cnc([nH]c2=N)[NH-], SAMPL8-14_micro007.
# Conformer generated for Cc1cc(cc(c1O)C(C)(C)C)Cc2c[nH]c(=N)[n-]c2=N, SAMPL8-14_micro09.
# Conformer generated for Cc1cc(cc(c1O)C(C)(C)C)Cc2c[n-]c(nc2=N)N, SAMPL8-14_micro010.
# Conformer generated for Cc1cc(cc(c1O)C(C)(C)C)Cc2c[nH]c(=N)nc2N, SAMPL8-14_micro013.
# Conformer generated for Cc1cc(cc(c1[O-])C(C)(C)C)Cc2cnc(=N)[n-]c2[NH-], SAMPL8-14_micro014.
# Conformer generated for Cc1cc(cc(c1[O-])C(C)(C)C)Cc2c[n-]c([nH+]c2=N)[NH-], SAMPL8-14_micro015.
# Conformer generated for Cc1cc(cc(c1O)C(C)(C)C)Cc2cnc(=N)[nH]c2N, SAMPL8-14_micro016.
# Conformer generated for Cc1cc(cc(c1O)C(C)(C)C)Cc2c[nH]c(nc2=N)N, SAMPL8-14_micro017.
# Conformer generated for Cc1cc(cc(c1O)C(C)(C)C)Cc2cnc([n-]c2=N)[NH-], SAMPL8-14_micro018.
# Conformer generated for Cc1cc(cc(c1[O-])C(C)(C)C)Cc2c[nH]c(=N)[n-]c2=N, SAMPL8-14_micro020.
# Conformer generated for Cc1cc(cc(c1O)C(C)(C)C)Cc2cnc([nH]c2=N)[NH-], SAMPL8-14_micro021.
# Conformer generated for Cc1cc(cc(c1[O-])C(C)(C)C)Cc2c[nH]c(nc2=N)N, SAMPL8-14_micro022.
# Conformer generated for Cc1cc(cc(c1O)C(C)(C)C)Cc2cnc([nH]c2=N)N, SAMPL8-14_micro023.
# Conformer generated for Cc1cc(cc(c1O)C(C)(C)C)Cc2c[n-]c([nH+]c2=N)[NH-], SAMPL8-14_micro025.
# Conformer generated for Cc1cc(cc(c1[O-])C(C)(C)C)Cc2c[nH+]c(=N)[n-]c2[NH-], SAMPL8-14_micro026.
# Conformer generated for Cc1cc(cc(c1[O-])C(C)(C)C)Cc2c[nH]c(=N)[nH]c2=N, SAMPL8-14_micro027.
# Conformer generated for Cc1cc(cc(c1[O-])C(C)(C)C)Cc2c[nH]c(=N)nc2N, SAMPL8-14_micro028.
# Conformer generated for Cc1cc(cc(c1[O-])C(C)(C)C)Cc2cnc(=N)[nH]c2N, SAMPL8-14_micro029.
# Conformer generated for Cc1cc(cc(c1O)C(C)(C)C)Cc2c[nH]c(nc2=N)N, SAMPL8-14_micro030.
# Conformer generated for Cc1cc(cc(c1[O-])C(C)(C)C)Cc2cnc([nH]c2=N)N, SAMPL8-14_micro032.
# Conformer generated for Cc1cc(cc(c1O)C(C)(C)C)Cc2c[nH]c(=N)nc2N, SAMPL8-14_micro033.
# Conformer generated for Cc1cc(cc(c1O)C(C)(C)C)Cc2c[nH]c(=N)[nH]c2=N, SAMPL8-14_micro034.
# Conformer generated for c1ccc(c(c1)C=C(O)[O-])Nc2c(cccc2Cl)Cl, SAMPL8-5_micro002.
# Conformer generated for c1ccc(c(c1)C=C(O)[O-])[NH2+]c2c(cccc2Cl)Cl, SAMPL8-5_micro004.
# Conformer generated for COc1cc(cc(c1O)OC)Cc2c(=N)[nH]c(=N)[nH]c2OC, SAMPL8-21_micro000.
# Conformer generated for COc1cc(cc(c1[O-])OC)Cc2c(=N)[nH+]c([n-]c2OC)[NH-], SAMPL8-21_micro001.
# Conformer generated for COc1cc(cc(c1[O-])OC)Cc2c(=N)nc([nH]c2OC)[NH-], SAMPL8-21_micro004.
# Conformer generated for COc1cc(cc(c1[O-])OC)Cc2c(=N)[n-]c(=[NH2+])[n-]c2OC, SAMPL8-21_micro005.
# Conformer generated for COc1cc(cc(c1O)OC)Cc2c(=N)[nH]c(=N)[n-]c2OC, SAMPL8-21_micro006.
# Conformer generated for COc1cc(cc(c1O)OC)Cc2c(=N)[n-]c(=N)[nH]c2OC, SAMPL8-21_micro007.
# Conformer generated for COc1cc(cc(c1O)OC)Cc2c(=N)nc([nH]c2OC)N, SAMPL8-21_micro008.
# Conformer generated for COc1cc(cc(c1[O-])OC)Cc2c(=N)[n-]c(nc2OC)[NH-], SAMPL8-21_micro010.
# Conformer generated for COc1cc(cc(c1O)OC)Cc2c([nH+]c(=N)[n-]c2OC)[NH-], SAMPL8-21_micro011.
# Conformer generated for COc1cc(cc(c1O)OC)Cc2c(=N)nc([n-]c2OC)[NH-], SAMPL8-21_micro012.
# Conformer generated for COc1cc(cc(c1[O-])OC)Cc2c(=N)[nH]c(nc2OC)[NH-], SAMPL8-21_micro013.
# Conformer generated for COc1cc(cc(c1O)OC)Cc2c([n-]c(=N)nc2OC)N, SAMPL8-21_micro014.
# Conformer generated for COc1cc(cc(c1[O-])OC)Cc2c(nc(=N)[n-]c2OC)N, SAMPL8-21_micro017.
# Conformer generated for COc1cc(cc(c1[O-])OC)Cc2c(=N)[nH]c(nc2OC)N, SAMPL8-21_micro018.
# Conformer generated for COc1cc(cc(c1O)OC)Cc2c([n-]c(=N)[nH+]c2OC)[NH-], SAMPL8-21_micro019.
# Conformer generated for COc1cc(cc(c1[O-])OC)Cc2c(nc(=N)[nH]c2OC)N, SAMPL8-21_micro020.
# Conformer generated for COc1cc(cc(c1[O-])OC)Cc2c(=N)[n-]c(nc2OC)N, SAMPL8-21_micro021.
# Conformer generated for COc1cc(cc(c1O)OC)Cc2c(=N)[nH]c(nc2OC)N, SAMPL8-21_micro023.
# Conformer generated for COc1cc(cc(c1[O-])OC)Cc2c([nH]c(=N)nc2OC)N, SAMPL8-21_micro024.
# Conformer generated for COc1cc(cc(c1O)OC)Cc2c([nH]c(=N)nc2OC)N, SAMPL8-21_micro025.
# Conformer generated for COc1cc(cc(c1[O-])OC)Cc2c(=N)nc([nH]c2OC)N, SAMPL8-21_micro026.
# Conformer generated for COc1cc(cc(c1[O-])OC)Cc2c(=N)[nH]c(=N)[nH]c2OC, SAMPL8-21_micro027.
# Conformer generated for COc1cc(cc(c1O)OC)Cc2c(nc(=N)[nH]c2OC)N, SAMPL8-21_micro029.
# Conformer generated for CS(=O)(=O)c1ccc(cc1)CC=C(O)[O-], SAMPL8-2_micro003.
